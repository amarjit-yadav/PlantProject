# %% [markdown]
# # course of action
#
# `1) problem defination`
#
# `2) data`
#
# `3) features`
#
# `4) evalutaion`
#
# `5) eda`
#
# `6) modeling`
#
# `7) model evaluation and prediction`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline

from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# ttdata=pd.read_csv('\plantclef dataset\trusted\PlantCLEF2022_trusted_training_metadata.csv')
# wtdata=pd.read_csv('\plantclef dataset\web\PlantCLEF2022_web_training_metadata.csv')

# linux
ttdata=pd.read_csv(r'/home/drowsy/Downloads/data/PlantCLEF2022_trusted_training_metadata.csv',delimiter=';')
wtdata=pd.read_csv(r'/home/drowsy/Downloads/data/PlantCLEF2022_web_training_metadata.csv',delimiter=';')

ttdata.head()
wtdata.head()
# Out:
#    classid                                    image_name  \
# 0  2683260  f402e9eb580a5a46470e60aae20c9239971f95ac.jpg
# 1  2683260  2ffcb2e0dd5a93697a7e37c4dee3fdcdff2a7914.jpg
# 2  2683260  987a5e1aaf1447a759ff75c3bbdf9bd7edac896f.jpg
# 3  2683260  4be17a768060b5b3f0ca4d340971ca7be3c90eb4.jpg
# 4  2683260  409ba823af52a3422de929d9344d1c8cd36cf4c3.jpg
#
#                                           image_path               species  \
# 0  2683260/f402e9eb580a5a46470e60aae20c9239971f95...  Cycas angulata R.Br.
# 1  2683260/2ffcb2e0dd5a93697a7e37c4dee3fdcdff2a79...  Cycas angulata R.Br.
# 2  2683260/987a5e1aaf1447a759ff75c3bbdf9bd7edac89...  Cycas angulata R.Br.
# 3  2683260/4be17a768060b5b3f0ca4d340971ca7be3c90e...  Cycas angulata R.Br.
# 4  2683260/409ba823af52a3422de929d9344d1c8cd36cf4...  Cycas angulata R.Br.
#
#    genus      family      order        class manual_tag predicted_tag  \
# 0  Cycas  Cycadaceae  Cycadales  Cycadopsida        NaN          bark
# 1  Cycas  Cycadaceae  Cycadales  Cycadopsida        NaN        flower
# 2  Cycas  Cycadaceae  Cycadales  Cycadopsida        NaN         habit
# 3  Cycas  Cycadaceae  Cycadales  Cycadopsida        NaN         habit
# 4  Cycas  Cycadaceae  Cycadales  Cycadopsida        NaN         habit
#
#    predicted_tag_probability  \
# 0                     0.2548
# 1                     0.8808
# 2                     0.6492
# 3                     0.9409
# 4                     0.9162
#
#                                         original_url  \
# 0  http://wonderplantsjapan.com/wp-content/upload...
# 1  http://toptropicals.com/pics/garden/m1/EleNZ2/...
# 2  http://farm5.staticflickr.com/4120/4865930312_...
# 3  http://pics.davesgarden.com/pics/2009/10/05/tr...
# 4  http://www.junglemusic.net/Water_Conservation_...
#
#                                     image_backup_url
# 0  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 1  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 2  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 3  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 4  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...

# %%
ttdata.head()
# Out:
#    classid                                    image_name  \
# 0  2683260  d0749fe4f8ade13dd9402b0f43bc29e8f28af27a.jpg
# 1  2683260  7549c8ddadd95d996e10aa76f8e39bedb059c637.jpg
# 2  2683260  8c6049ebdff482b901f32e0ac9e421c69bc652b4.jpg
# 3  2683260  b932fd8619c667a5b4f3c38596911937a2692b26.jpg
# 4  2683260  9f9dbdb0b9ce8bc3fb562f648af7717b5511b597.jpg
#
#                                           image_path               species  \
# 0  2683260/d0749fe4f8ade13dd9402b0f43bc29e8f28af2...  Cycas angulata R.Br.
# 1  2683260/7549c8ddadd95d996e10aa76f8e39bedb059c6...  Cycas angulata R.Br.
# 2  2683260/8c6049ebdff482b901f32e0ac9e421c69bc652...  Cycas angulata R.Br.
# 3  2683260/b932fd8619c667a5b4f3c38596911937a2692b...  Cycas angulata R.Br.
# 4  2683260/9f9dbdb0b9ce8bc3fb562f648af7717b5511b5...  Cycas angulata R.Br.
#
#    genus      family      order        class source manual_tag predicted_tag  \
# 0  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN        NaN         habit
# 1  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN        NaN         habit
# 2  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN        NaN         habit
# 3  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN        NaN         habit
# 4  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN        NaN         habit
#
#    predicted_tag_probability  \
# 0                     0.7386
# 1                     0.7938
# 2                     0.8785
# 3                     0.9218
# 4                     0.9318
#
#                                         original_url  \
# 0  https://images.ala.org.au/image/proxyImageThum...
# 1  https://images.ala.org.au/image/proxyImageThum...
# 2  https://images.ala.org.au/image/proxyImageThum...
# 3  https://images.ala.org.au/image/proxyImageThum...
# 4  https://images.ala.org.au/image/proxyImageThum...
#
#                                        license  \
# 0  http://creativecommons.org/licenses/by/4.0/
# 1  http://creativecommons.org/licenses/by/4.0/
# 2  http://creativecommons.org/licenses/by/4.0/
# 3  http://creativecommons.org/licenses/by/4.0/
# 4  http://creativecommons.org/licenses/by/4.0/
#
#                            publisher  gbif_occurrence_id aggregator  \
# 0  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 1  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 2  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 3  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 4  ALA species sightings and OzAtlas        1.632965e+09       gbif
#
#                             dataset_key  \
# 0  84a649ce-ff81-420d-9c41-aa1de59e3766
# 1  84a649ce-ff81-420d-9c41-aa1de59e3766
# 2  84a649ce-ff81-420d-9c41-aa1de59e3766
# 3  84a649ce-ff81-420d-9c41-aa1de59e3766
# 4  84a649ce-ff81-420d-9c41-aa1de59e3766
#
#                                     image_backup_url
# 0  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 1  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 2  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 3  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 4  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...

# %%
ttdata.shape
# Out:
# (2886761, 19)

# %%
wtdata.shape
# Out:
# (1071627, 13)

# %%
ttdata.select_dtypes('object').columns
# Out:
# Index(['image_name', 'image_path', 'species', 'genus', 'family', 'order',
#        'class', 'source', 'manual_tag', 'predicted_tag', 'original_url',
#        'license', 'publisher', 'aggregator', 'dataset_key',
#        'image_backup_url'],
#       dtype='object')

# %%
wtdata.select_dtypes('object').columns
# Out:
# Index(['image_name', 'image_path', 'species', 'genus', 'family', 'order',
#        'class', 'manual_tag', 'predicted_tag', 'original_url',
#        'image_backup_url'],
#       dtype='object')

# %%
len(ttdata.select_dtypes('object').columns)
# Out:
# 16

# %%
len(wtdata.select_dtypes('object').columns)
# Out:
# 11

# %%
ttdata.isnull().sum()
# Out:
# classid                            0
# image_name                         0
# image_path                         0
# species                            0
# genus                              0
# family                             0
# order                              0
# class                              0
# source                         78543
# manual_tag                   2735290
# predicted_tag                      0
# predicted_tag_probability          0
# original_url                       0
# license                           47
# publisher                         20
# gbif_occurrence_id             67697
# aggregator                         0
# dataset_key                    67697
# image_backup_url                   0
# dtype: int64

# %%
wtdata.isnull().sum()
# Out:
# classid                            0
# image_name                         0
# image_path                         0
# species                            0
# genus                              0
# family                             0
# order                              0
# class                              0
# manual_tag                   1070380
# predicted_tag                      0
# predicted_tag_probability          0
# original_url                       0
# image_backup_url                   0
# dtype: int64

# %%
ttdata.isnull().sum()/ttdata.shape[0]
# Out:
# classid                      0.000000
# image_name                   0.000000
# image_path                   0.000000
# species                      0.000000
# genus                        0.000000
# family                       0.000000
# order                        0.000000
# class                        0.000000
# source                       0.027208
# manual_tag                   0.947529
# predicted_tag                0.000000
# predicted_tag_probability    0.000000
# original_url                 0.000000
# license                      0.000016
# publisher                    0.000007
# gbif_occurrence_id           0.023451
# aggregator                   0.000000
# dataset_key                  0.023451
# image_backup_url             0.000000
# dtype: float64

# %%
wtdata.isnull().sum()/wtdata.shape[0]
# Out:
# classid                      0.000000
# image_name                   0.000000
# image_path                   0.000000
# species                      0.000000
# genus                        0.000000
# family                       0.000000
# order                        0.000000
# class                        0.000000
# manual_tag                   0.998836
# predicted_tag                0.000000
# predicted_tag_probability    0.000000
# original_url                 0.000000
# image_backup_url             0.000000
# dtype: float64

# %%
ttdata.drop(columns=['manual_tag'],inplace=True)
wtdata.drop(columns=['manual_tag'],inplace=True)

# %%
wtdata.columns
# Out:
# Index(['classid', 'image_name', 'image_path', 'species', 'genus', 'family',
#        'order', 'class', 'predicted_tag', 'predicted_tag_probability',
#        'original_url', 'image_backup_url'],
#       dtype='object')

# %%
ttdata.head()
# Out:
#    classid                                    image_name  \
# 0  2683260  d0749fe4f8ade13dd9402b0f43bc29e8f28af27a.jpg
# 1  2683260  7549c8ddadd95d996e10aa76f8e39bedb059c637.jpg
# 2  2683260  8c6049ebdff482b901f32e0ac9e421c69bc652b4.jpg
# 3  2683260  b932fd8619c667a5b4f3c38596911937a2692b26.jpg
# 4  2683260  9f9dbdb0b9ce8bc3fb562f648af7717b5511b597.jpg
#
#                                           image_path               species  \
# 0  2683260/d0749fe4f8ade13dd9402b0f43bc29e8f28af2...  Cycas angulata R.Br.
# 1  2683260/7549c8ddadd95d996e10aa76f8e39bedb059c6...  Cycas angulata R.Br.
# 2  2683260/8c6049ebdff482b901f32e0ac9e421c69bc652...  Cycas angulata R.Br.
# 3  2683260/b932fd8619c667a5b4f3c38596911937a2692b...  Cycas angulata R.Br.
# 4  2683260/9f9dbdb0b9ce8bc3fb562f648af7717b5511b5...  Cycas angulata R.Br.
#
#    genus      family      order        class source predicted_tag  \
# 0  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN         habit
# 1  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN         habit
# 2  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN         habit
# 3  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN         habit
# 4  Cycas  Cycadaceae  Cycadales  Cycadopsida    NaN         habit
#
#    predicted_tag_probability  \
# 0                     0.7386
# 1                     0.7938
# 2                     0.8785
# 3                     0.9218
# 4                     0.9318
#
#                                         original_url  \
# 0  https://images.ala.org.au/image/proxyImageThum...
# 1  https://images.ala.org.au/image/proxyImageThum...
# 2  https://images.ala.org.au/image/proxyImageThum...
# 3  https://images.ala.org.au/image/proxyImageThum...
# 4  https://images.ala.org.au/image/proxyImageThum...
#
#                                        license  \
# 0  http://creativecommons.org/licenses/by/4.0/
# 1  http://creativecommons.org/licenses/by/4.0/
# 2  http://creativecommons.org/licenses/by/4.0/
# 3  http://creativecommons.org/licenses/by/4.0/
# 4  http://creativecommons.org/licenses/by/4.0/
#
#                            publisher  gbif_occurrence_id aggregator  \
# 0  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 1  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 2  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 3  ALA species sightings and OzAtlas        1.632965e+09       gbif
# 4  ALA species sightings and OzAtlas        1.632965e+09       gbif
#
#                             dataset_key  \
# 0  84a649ce-ff81-420d-9c41-aa1de59e3766
# 1  84a649ce-ff81-420d-9c41-aa1de59e3766
# 2  84a649ce-ff81-420d-9c41-aa1de59e3766
# 3  84a649ce-ff81-420d-9c41-aa1de59e3766
# 4  84a649ce-ff81-420d-9c41-aa1de59e3766
#
#                                     image_backup_url
# 0  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 1  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 2  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 3  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
# 4  https://lab.plantnet.org/LifeCLEF/PlantCLEF202...
